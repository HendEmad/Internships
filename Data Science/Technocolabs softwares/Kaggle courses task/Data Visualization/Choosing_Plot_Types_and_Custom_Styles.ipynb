# %% [markdown]
# # Changing styles with seaborn

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
spotify_data = pd.read_csv("spotify.csv", index_col = "Date", parse_dates = True)

# Line chart
plt.figure(figsize = (12, 6))
sns.lineplot(data  = spotify_data)

# %%
# Change the style of the figure to the dark theme
sns.set_style("dark")

# Line chart
plt.figure(figsize = (12, 6))
sns.lineplot(data  = spotify_data)

# %% [markdown]
# Seaborn has 5 themes:
# (darkgrid / whitegrid / dark / white / ticks) --> we use `sns.set_style("preferred_theme")` to change it.
